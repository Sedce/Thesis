# %%
import lyricsgenius as genius
import pandas as pd
import csv
import os

api = genius.Genius('ktWg_XmK_iU3IUoQ1lBJIyti-IrCFZiUJmEJlt_KeWWnkfoIjlNZoEYbMXw8WLVq')
#artist = api.search_artist('Justin Bieber', max_songs=4)
#print(artist.songs[1].lyrics)
#print(artist[1])
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)
        
sp = pd.read_csv('artists_alive.csv', sep=',', encoding = "ISO-8859-1")
artists = sp.Artist          
for i in range(len(artists)):
   # createFolder('C:/Users/Cedezmarie/Desktop/Thesis/alive_musicians/' + artists[i] + '/' )
    artist = api.search_artist(str(artists[i]), max_songs=4)
    for j in range(len(artist.songs)):
        f = open("C:/Users/Cedezmarie/Desktop/Thesis/alive_musicians/" + artists[i] + "/" +artist.songs[j].title.replace('?','')+ ".txt","w")
        f.write(artist.songs[j].lyrics)
        f.close()
# Out:
# Searching for Hozier...
#
# Song 1: "Alright*"
# Song 2: "Angel of Small Death & the Codeine Scene"
# Song 3: "Arsonist's Lullabye"
# Song 4: "Better Love"
#
# Reached user-specified song limit (4).
# Found 4 songs.
# Done.
# Searching for Hayley Williams...
#
# Song 1: "Bad Romance"
# Song 2: "Hayley Williams' Hair Evolution"
# Song 3: "Hayley Williams' Tattoos"
# Timeout raised and caught
# Timeout raised and caught
# Timeout raised and caught
# Timeout raised and caught
# Timeout raised and caught
# Timeout raised and caught
# Timeout raised and caught
# Timeout raised and caught
# Timeout raised and caught
# Timeout raised and caught
# Timeout raised and caught
# Timeout raised and caught
# Timeout raised and caught
# Song 4: "Nineteen"
#
# Reached user-specified song limit (4).
# Found 4 songs.
# Done.
# Searching for Big Sean...
#
# Song 1: "100"
# Song 2: "100 Dollar Bill Skyscraper"
# Song 3: "100 Keys"
# Song 4: "10 2 10"
#
# Reached user-specified song limit (4).
# Found 4 songs.
# Done.
# Searching for Kanye West...
#
# Song 1: "'03 Electric Relaxation"
# Song 2: "18 Years"
# Song 3: "1996 Fat Beats Freestyle"
# Song 4: "2002 Unreleased Freestyle"
#
# Reached user-specified song limit (4).
# Found 4 songs.
# Done.
# Searching for Calvin Harris...
#
# Song 1: "5am"
# Song 2: "5iliconeator"
# Song 3: "Acceptable in the 80s"
# Song 4: "Acceptable in the 80's - edit"
#
# Reached user-specified song limit (4).
# Found 4 songs.
# Done.
# Searching for Jessie J...
#
# Song 1: "Abracadabra"
# Song 2: "Ain't Been Done"
# Song 3: "Alive"
# Song 4: "Bang Bang (Solo Version)"
#
# Reached user-specified song limit (4).
# Found 4 songs.
# Done.
# Searching for John Lennon...
#
# Song 1: "#9 Dream"
# Song 2: "A Day In The Life"
# Song 3: "Ain't She Sweet"
# Song 4: "Ain't That A Shame"
#
# Reached user-specified song limit (4).
# Found 4 songs.
# Done.
# Searching for Leona Lewis...
#
# Song 1: "Alive"
# Song 2: "A Moment Like This"
# Song 3: "Angel"
# Song 4: "Another Love Song"
#
# Reached user-specified song limit (4).
# Found 4 songs.
# Done.
# Searching for Gary Lightbody...
#
# Song 1: "Some surprise"
# Found 1 songs.
# Done.
# Searching for Limahl...
#
# Song 1: "Inside To Outside"
# Song 2: "Love In Your Eyes"
# Song 3: "Only For Love"
# Song 4: "Tar Beach"
#
# Reached user-specified song limit (4).
# Found 4 songs.
# Done.
# Searching for Cher Lloyd...
#
# Song 1: "Activated"
# Song 2: "Alone With Me"
# Song 3: "Beautiful People"
# Song 4: "Behind The Music"
#
# Reached user-specified song limit (4).
# Found 4 songs.
# Done.
# Searching for Rita Ora...
#
# Song 1: "All That I Want*"
# Song 2: "Anywhere"
# Song 3: "Anywhere (R3hab Remix)"
# Song 4: "Anywhere (Willy William Remix)"
#
# Reached user-specified song limit (4).
# Found 4 songs.
# Done.
# Searching for John Otway...
#
# Song 1: "A413 Revisited"
# Song 2: "Best Dream"
# Song 3: "Beware Of The Flowers"
# Song 4: "Beware Of The Flowers ('Cos I'm Sure They're Going To Get You Yeah!)"
#
# Reached user-specified song limit (4).
# Found 4 songs.
# Done.
# Searching for Bill Owen...
#
# Couldn't find Bill Owen. Did you mean Owen Campbell? (y/n): y
# Song 1: "A Better Place"
# Song 2: "A Mountain Home"
# Song 3: "Bukhu's Blues (Mongolian Instrumental)"
# Song 4: "Days Like This"
#
# Reached user-specified song limit (4).
# Found 4 songs.
# Done.
# Searching for Mark Owen...
#
# Song 1: "3:15"
# Song 2: "Alone Without You"
# Song 3: "Animals"
# Song 4: "Are You With Me?"
#
# Reached user-specified song limit (4).
# Found 4 songs.
# Done.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-1cc022628dff> in <module>()
#      21     artist = api.search_artist(str(artists[i]), max_songs=4)
#      22     for j in range(len(artist.songs)):
# ---> 23         f = open("C:/Users/Cedezmarie/Desktop/Thesis/alive_musicians/" + artists[i] + "/" +artist.songs[j].title.replace('*','')+ ".txt","w")
#      24         f.write(artist.songs[j].lyrics)
#      25         f.close()
#
# OSError: [Errno 22] Invalid argument: 'C:/Users/Cedezmarie/Desktop/Thesis/alive_musicians/Mark Owen/Are You With Me?.txt'
